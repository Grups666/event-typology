# %%
import sys
import os
sys.path.insert(0, os.path.abspath("../"))

from codebase import (
    generate_figure_1,
    generate_figure_2,
    generate_figure_3,
    generate_figure_4,
    generate_figure_5,
    generate_figure_s1,
    generate_figure_s2,
    generate_figure_s3,
    generate_figure_s4,
    generate_figure_s6,
    generate_figure_s7,
    FigureConfig
)

# %% [markdown]
# ## Configuration
#
# All parameters can be customized via `FigureConfig`. If not specified, default values are used.

# %%
# Optional: Customize configuration (all parameters have defaults)
config = FigureConfig(
    # figures_base_path='figures',
    # show_dpi=100,  # DPI for displaying figures
    # save_dpi=300,  # DPI for saving figures
    # default_regions=['oceania', 'southern_africa', 'europe', 'north_america', 'south_america', 'southeast_asia'],  # Regions used by Figure 1 and Figure 2
    # ... other parameters
)

data_folder = 'Your Data Folder Path/'

# %% [markdown]
# ## Main Figures (Figure 1-5)
#
# #### Figure 1: Regional Catchment Type Maps (Dormant Season)
#
# **Note**: When `save=True` and `show=False`, automatically generates main map (`Spatial_Distribution.png`) + panels (`Longitudinal_Distribution.png`, `Latitudinal_Distribution.png`, `Type_Composition.png`). When `show=True`, only displays the main map.

# %%
# Show example: Display one region without saving (only main map shown)
generate_figure_1(region='north_america', season='dormant', data_folder=data_folder, save=False, show=True, config=config)

# %%
# Generate all regions: Save main map + panels for all regions (region=None means all regions from config.default_regions)
# This will save: Spatial_Distribution.png, Longitudinal_Distribution.png, Latitudinal_Distribution.png, Type_Composition.png
# generate_figure_1(region=None, season='dormant', data_folder=data_folder, save=True, show=False, config=config)

# %% [markdown]
# ## Figure 2: Seasonal Transition Analysis
#
# Generates `{Region_Name}_Seasonal_Transition.png` for each region in `Fig. 2/`.

# %%
# Show example: Display one region without saving
# color_source can be 'hollow' (default), 'dormant', or 'growing'
generate_figure_2(region='north_america', color_source='hollow', data_folder=data_folder, save=False, show=True, config=config)

# %%
# Generate all regions: Save all figures without showing (region=None means all regions)
# You can specify color_source: 'hollow', 'dormant', or 'growing'
# generate_figure_2(region=None, color_source='hollow', data_folder=data_folder, save=True, show=False, config=config)

# %% [markdown]
# ## Figure 3: Coherence Consistency Heatmap
#
# Generates `Heatmap_Coherence_Consistency_dormant.png` in `Fig. 3/`.

# %%
# Show example: Display dormant season heatmap without saving
generate_figure_3(season='dormant', data_folder=data_folder, save=False, show=True, config=config)

# %%
# Generate main figure: Save dormant season heatmap (Figure 3)
# generate_figure_3(season='dormant', data_folder=data_folder, save=True, show=False, config=config)

# %% [markdown]
# ## Figure 4: Magnitude CV by Coherency
#
# Generates `Mag_CV_vs_coherency_dormant_Rain.png` in `Fig. 4/`.

# %%
# Show example: Display dormant season magnitude CV without saving
generate_figure_4(season='dormant', data_folder=data_folder, save=False, show=True, config=config)

# %%
# Generate main figure: Save dormant season magnitude CV (Figure 4)
# generate_figure_4(season='dormant', data_folder=data_folder, save=True, show=False, config=config)

# %% [markdown]
# ## Figure 5: Hydrologic Response Comparison
#
# Generates `Mag_comparison_Combined_CDF.png` in `Fig. 5/`.

# %%
# Show example: Display dormant season hydrologic response without saving
generate_figure_5(season='dormant', data_folder=data_folder, save=False, show=True, config=config)

# %%
# Generate main figure: Save dormant season hydrologic response (Figure 5)
# generate_figure_5(season='dormant', data_folder=data_folder, save=True, show=False, config=config)

# %% [markdown]
# # Supplementary Figures (Figure S1-S7)
#
# ## Figure S1: SSI CDF
#
# Generates `SSI_CDF.png` in `Fig. S1/`.

# %%
# Generate and save: Save SSI CDF figure without showing
# generate_figure_s1(data_folder=data_folder, save=True, show=False, config=config)

# %% [markdown]
# ## Figure S2: Global Catchment Type Maps
#
# Generates `Spatial_Distribution_{season}.png` for dormant and growing seasons in `Fig. S2/`.

# %%
# Generate all seasons: Save both dormant and growing season global maps without showing
# generate_figure_s2(season='dormant', data_folder=data_folder, save=True, show=False, config=config)
# generate_figure_s2(season='growing', data_folder=data_folder, save=True, show=False, config=config)

# %% [markdown]
# ## Figure S3: Regional Catchment Type Maps (Growing Season)
#
# **Note**: When `save=True` and `show=False`, automatically generates main map (`Spatial_Distribution.png`) + panels (`Longitudinal_Distribution.png`, `Latitudinal_Distribution.png`, `Type_Composition.png`). When `show=True`, only displays the main map.

# %%
# Generate all regions: Save main map + panels for all regions (region=None means all regions from config.default_regions)
# This will save: Spatial_Distribution.png, Longitudinal_Distribution.png, Latitudinal_Distribution.png, Type_Composition.png
# generate_figure_s3(region=None, data_folder=data_folder, save=True, show=False, config=config)

# %% [markdown]
# ## Figure S4: Consistency Boxplot
#
# Generates `Consistency_Boxplot_{season}.png` for dormant and growing seasons in `Fig. S4/`.

# %%
# Generate all seasons: Save both dormant and growing season boxplots without showing
# generate_figure_s4(season='dormant', data_folder=data_folder, save=True, show=False, config=config)
# generate_figure_s4(season='growing', data_folder=data_folder, save=True, show=False, config=config)

# %% [markdown]
# ## Figure S5: Coherence Consistency Heatmap (Growing Season)
#
# Generates `Heatmap_Coherence_Consistency_growing.png` in `Fig. S5/`.

# %%
# Generate supplementary figure: Save growing season heatmap (Figure S5)
# generate_figure_3(season='growing', data_folder=data_folder, save=True, show=False, config=config)

# %% [markdown]
# ## Figure S6: Magnitude CV by Coherency (Growing Season)
#
# Generates `Mag_CV_vs_Coherency_growing.png` in `Fig. S6/`.

# %%
# Generate supplementary figure: Save growing season magnitude CV (Figure S6)
# generate_figure_4(season='growing', data_folder=data_folder, save=True, show=False, config=config)

# %% [markdown]
# ## Figure S7: Hydrologic Response Comparison (Growing Season)
#
# Generates `Mag_Comparison_Combined_CDF.png` in `Fig. S7/`.

# %%
# Generate supplementary figure: Save growing season hydrologic response (Figure S7)
# generate_figure_5(season='growing', data_folder=data_folder, save=True, show=False, config=config)
